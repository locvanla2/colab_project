# %% [markdown]
# <a href="https://colab.research.google.com/github/locvanla2/colab_project/blob/main/pandas_lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/ColabNotebooks/resources/query_total_user_login_20240701_20240731.csv'
df = pd.read_csv(path)
df.head()
#df.drop_duplicates(inplace=True)
#df.to_csv('/content/drive/MyDrive/ColabNotebooks/resources/query_total_user_login_2.csv',index=False)


#import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          date         uId  Unnamed: 2
# 0  2024-07-01  1098305901         NaN
# 1  2024-07-01  1319781097         NaN
# 2  2024-07-01   592741010         NaN
# 3  2024-07-01   312381881         NaN
# 4  2024-07-01  1318937707         NaN

# %%
df.drop_duplicates(inplace=True)
#df = df.drop(df.columns[2], axis=1)
#df.head()
df.to_csv('/content/drive/MyDrive/ColabNotebooks/resources/query_total_user_login_2.csv',index=False)
# Out:
#          date         uId
# 0  2024-07-01  1098305901
# 1  2024-07-01  1319781097
# 2  2024-07-01   592741010
# 3  2024-07-01   312381881
# 4  2024-07-01  1318937707
